# %%
name = input("Enter your name: ")
times = int(input("Enter a number: "))

print("I am going to say your name " + str(times) + " times")
print((name + " ") * times)
# Out:
# Enter your name:  oliver
# Enter a number:  10
# I am going to say your name 10 times
# oliver oliver oliver oliver oliver oliver oliver oliver oliver oliver
